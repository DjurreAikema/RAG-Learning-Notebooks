# %% [markdown]
# # 🦙 Local RAG Q&A Chatbot — Tutorial Notebook
#
# A **fully local** question-answering bot that answers using *your own* company documents.
# Nothing leaves your machine: the LLM, the embeddings, and the vector database all run locally.
#
# **Stack**
# - **Ollama** — runs the LLM (`llama3.1:8b`) and the embedding model locally
# - **LangChain** — wires the pipeline together
# - **Chroma** — local vector database (stores your documents as searchable vectors)
# - **Jupyter** — where we build and experiment
#
# ### What is RAG, in one picture?
#
# ```
#                     ┌─────────────────────────────────────────────┐
#    Your docs  ──►   │ 1. LOAD   2. SPLIT   3. EMBED   4. STORE     │   (done once, "indexing")
#                     └─────────────────────────────────────────────┘
#                                         │
#                                    Chroma vector DB
#                                         │
#    Your question ──► 5. RETRIEVE relevant chunks ──► 6. AUGMENT the prompt ──► 7. GENERATE answer
# ```
#
# Without RAG, the model answers only from what it was trained on. With RAG, we **retrieve** the most
# relevant chunks of *your* documents and hand them to the model as context, so answers are grounded
# in your data. We'll build each numbered step below, one cell at a time.

# %% [markdown]
# ## Step 0 — Before you run anything
#
# This notebook assumes you've already done the terminal setup (see the project `README.md`):
#
# 1. Installed **Ollama** for Windows and it's running (you'll see the llama icon in your system tray).
# 2. Pulled the two models:
#    ```
#    ollama pull llama3.1:8b
#    ollama pull nomic-embed-text
#    ```
# 3. Created & activated a virtual environment and installed the Python packages.
#
# The very first cell just checks that Ollama is alive and the models are present. If it fails,
# go back to the README — don't continue until this passes.

# %%
# --- Sanity check: is Ollama running and are our models installed? ---
import requests

try:
    resp = requests.get("http://localhost:11434/api/tags", timeout=5)
    resp.raise_for_status()
    installed = [m["name"] for m in resp.json().get("models", [])]
    print("✅ Ollama is running.")
    print("Installed models:", installed)
    for needed in ("llama3.1:8b", "nomic-embed-text:latest"):
        base = needed.split(":")[0]
        if any(m.startswith(base) for m in installed):
            print(f"  ✅ found a model matching '{base}'")
        else:
            print(f"  ❌ '{base}' not found — run:  ollama pull {needed.replace(':latest','')}")
except Exception as e:
    print("❌ Could not reach Ollama at http://localhost:11434")
    print("   Make sure the Ollama app is running, then re-run this cell.")
    print("   Error:", e)

# %% [markdown]
# ## Step 1 — Install the Python packages (only if you skipped the README)
#
# Best practice is to install these in your terminal (inside your activated venv) using
# `pip install -r requirements.txt`. But you *can* run it here once. The `%pip` magic installs
# into the same environment this notebook is using.
#
# If you already installed via the README, **skip this cell.**

# %%
# Run once if needed. Safe to skip if you used requirements.txt in the terminal.
# %pip install -q \
    langchain langchain-core langchain-community \
    langchain-ollama langchain-chroma langchain-text-splitters \
    pypdf docx2txt chromadb
print("Done. Restart the kernel if this was a fresh install.")

# %% [markdown]
# ## Step 2 — Configuration
#
# We keep all the "knobs" in one place. This is a good habit: when you want to try a bigger model
# or different chunk sizes, you change one cell instead of hunting through the notebook.
#
# - **`LLM_MODEL`** — the chat model that writes answers. `llama3.1:8b` is a great balance for your
#   RTX 3050 + 64 GB RAM. If answers feel slow, try `llama3.2:3b`; for more quality, `qwen2.5:14b`.
# - **`EMBED_MODEL`** — turns text into vectors. Keep this the **same** for indexing and querying.
# - **`CHUNK_SIZE` / `CHUNK_OVERLAP`** — how we cut documents into pieces (explained in Step 4).
# - **`N_RESULTS`** — how many chunks to retrieve per question.

# %%
from pathlib import Path

# --- Models (must match what you pulled in Ollama) ---
LLM_MODEL   = "llama3.1:8b"
EMBED_MODEL = "nomic-embed-text"

# --- Paths ---
DATA_DIR = Path("data")          # your company documents live here
DB_DIR   = "chroma_db"           # the vector database is persisted to this folder

# --- Chunking & retrieval knobs ---
CHUNK_SIZE    = 1000             # characters per chunk
CHUNK_OVERLAP = 150             # characters shared between neighbouring chunks
N_RESULTS     = 4               # how many chunks to feed the model per question

print("Config loaded. Documents folder:", DATA_DIR.resolve())

# %% [markdown]
# ## Step 3 — Load the documents
#
# You told me your files are a **mix of formats**, so we handle PDF, Word (`.docx`), plain text, and
# Markdown. LangChain gives us a dedicated *loader* for each type:
#
# | Extension        | Loader           |
# |------------------|------------------|
# | `.pdf`           | `PyPDFLoader`    |
# | `.docx`          | `Docx2txtLoader` |
# | `.txt` / `.md`   | `TextLoader`     |
#
# We walk the `data/` folder, pick the right loader per file, and load everything into a list of
# LangChain `Document` objects. Each Document carries the text **plus metadata** (like which file it
# came from) — that metadata is what lets us cite sources later.

# %%
from langchain_community.document_loaders import PyPDFLoader, Docx2txtLoader, TextLoader

def load_documents(folder: Path):
    documents = []
    files = [p for p in folder.rglob("*") if p.is_file()]
    if not files:
        print(f"⚠️  No files found in {folder.resolve()} — add some documents and re-run.")
        return documents

    for path in files:
        suffix = path.suffix.lower()
        try:
            if suffix == ".pdf":
                loader = PyPDFLoader(str(path))
            elif suffix == ".docx":
                loader = Docx2txtLoader(str(path))
            elif suffix in (".txt", ".md"):
                loader = TextLoader(str(path), autodetect_encoding=True)
            else:
                print(f"  ↷ skipping unsupported file: {path.name}")
                continue
            loaded = loader.load()
            documents.extend(loaded)
            print(f"  ✅ loaded {path.name}  ({len(loaded)} document object(s))")
        except Exception as e:
            print(f"  ❌ failed on {path.name}: {e}")

    print(f"\nTotal document objects loaded: {len(documents)}")
    return documents

docs = load_documents(DATA_DIR)

# %% [markdown]
# ## Step 4 — Split the documents into chunks
#
# Why split at all? Two reasons:
# 1. **Precision** — retrieving a whole 40-page PDF to answer one question is wasteful and dilutes the
#    context. Small chunks let us fetch just the relevant paragraphs.
# 2. **Model limits** — we can only fit so much text into the prompt.
#
# We use `RecursiveCharacterTextSplitter`, which tries to split on natural boundaries (paragraphs, then
# sentences, then words) so chunks stay coherent.
#
# - **`chunk_size`** — target characters per chunk. Smaller = more precise but more fragmented.
# - **`chunk_overlap`** — a few characters repeated between neighbours so a sentence split across the
#   boundary isn't lost. ~10–15% of chunk size is a good rule of thumb.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=CHUNK_SIZE,
    chunk_overlap=CHUNK_OVERLAP,
    separators=["\n\n", "\n", ". ", " ", ""],  # try these boundaries in order
)

chunks = splitter.split_documents(docs)
print(f"Split {len(docs)} document object(s) into {len(chunks)} chunks.")
if chunks:
    print("\n--- Example chunk ---")
    print("Source:", chunks[0].metadata.get("source"))
    print(chunks[0].page_content[:300], "...")

# %% [markdown]
# ## Step 5 — Embed the chunks and store them in Chroma
#
# An **embedding** is a list of numbers (a vector) that captures the *meaning* of a piece of text.
# Texts with similar meaning end up close together in vector space. That's the magic that lets us
# search by meaning instead of exact keywords.
#
# We use Ollama's `nomic-embed-text` model to embed each chunk, then store the vectors in **Chroma**,
# a local vector database. We pass `persist_directory` so the database is saved to disk — next time you
# can load it instantly instead of re-embedding everything.
#
# > **First run is the slow one.** Embedding every chunk takes a moment. After that it's cached on disk.

# %%
from langchain_ollama import OllamaEmbeddings
from langchain_chroma import Chroma

embeddings = OllamaEmbeddings(model=EMBED_MODEL)

# Build the vector store from our chunks and persist it to disk.
vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory=DB_DIR,
    collection_name="company_docs",
)
print(f"✅ Vector store ready with {vectorstore._collection.count()} vectors, saved to '{DB_DIR}/'.")

# %% [markdown]
# ### (Later runs) Load the existing database instead of rebuilding
#
# Once the database exists on disk, you don't need to re-run Steps 3–5. In a fresh session you can just
# run Step 2 (config) and then this cell to reconnect to the saved vectors. *(Skip it now — we already
# have `vectorstore` in memory.)*

# %%
# Use this in future sessions to skip re-indexing:
# from langchain_ollama import OllamaEmbeddings
# from langchain_chroma import Chroma
# embeddings = OllamaEmbeddings(model=EMBED_MODEL)
# vectorstore = Chroma(
#     persist_directory=DB_DIR,
#     embedding_function=embeddings,
#     collection_name="company_docs",
# )
# print("Reconnected to", vectorstore._collection.count(), "vectors.")

# %% [markdown]
# ## Step 6 — Create a retriever and test it
#
# A **retriever** is a thin wrapper around the vector store that, given a question, returns the
# `N_RESULTS` most similar chunks. Let's create one and sanity-check it *before* involving the LLM —
# if retrieval returns junk, the answer will be junk, so it's worth testing this piece on its own.

# %%
retriever = vectorstore.as_retriever(search_kwargs={"k": N_RESULTS})

# Try a question and see which chunks come back:
test_question = "What is the company's refund policy?"   # change to something in YOUR docs
hits = retriever.invoke(test_question)

print(f"Top {len(hits)} chunks for: {test_question!r}\n")
for i, doc in enumerate(hits, 1):
    src = doc.metadata.get("source", "unknown")
    print(f"[{i}] from {src}")
    print("   ", doc.page_content[:200].replace("\n", " "), "...\n")

# %% [markdown]
# ## Step 7 — Write the prompt template
#
# This is where **prompt templates** come in (one of the things you asked for). A template is a
# reusable prompt with placeholders we fill in at runtime. Ours has two placeholders:
#
# - `{context}` — the retrieved chunks get injected here
# - `{question}` — the user's question
#
# The **system message** sets the bot's behaviour. Notice we explicitly tell it to answer *only* from
# the provided context and to admit when it doesn't know — this is what keeps a RAG bot honest and
# stops it from making things up.

# %%
from langchain_core.prompts import ChatPromptTemplate

SYSTEM_PROMPT = (
    "You are a helpful assistant for answering questions about internal company documents. "
    "Use ONLY the pieces of context provided below to answer the question. "
    "If the answer is not contained in the context, say you don't know based on the available "
    "documents — do not invent information. Keep answers concise and cite which document you used."
)

prompt = ChatPromptTemplate.from_messages([
    ("system", SYSTEM_PROMPT),
    ("human", "Context:\n{context}\n\nQuestion: {question}\n\nAnswer:"),
])

print(prompt.format(context="<retrieved chunks go here>", question="<user question>"))

# %% [markdown]
# ## Step 8 — Assemble the RAG chain
#
# Now we connect everything using **LCEL** (LangChain Expression Language), where the `|` pipe passes
# output from one step to the next — just like a Unix pipe. Our chain does:
#
# ```
# {context: retriever→formatted, question: passthrough}  →  prompt  →  LLM  →  plain text
# ```
#
# `format_docs` turns the list of retrieved chunks into one tidy string (and tags each with its source
# so the model can cite it). `StrOutputParser` just extracts the plain-text answer from the model's
# response object.

# %%
from langchain_ollama import ChatOllama
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

llm = ChatOllama(model=LLM_MODEL, temperature=0)  # temperature=0 → focused, less "creative"

def format_docs(docs):
    # Combine retrieved chunks into a single context string, labelled by source.
    blocks = []
    for d in docs:
        src = d.metadata.get("source", "unknown")
        blocks.append(f"[Source: {src}]\n{d.page_content}")
    return "\n\n---\n\n".join(blocks)

rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

print("✅ RAG chain assembled and ready.")

# %% [markdown]
# ## Step 9 — Ask a question!
#
# Everything comes together here. Change the question to something answerable from *your* documents.

# %%
question = "What is the company's refund policy?"   # ← edit this
answer = rag_chain.invoke(question)
print(answer)

# %% [markdown]
# ### A tidier helper that also shows its sources
#
# Good RAG bots are *transparent* — they show which documents an answer came from so you can verify it.
# This helper returns the answer **and** the source chunks.

# %%
def ask(question: str, show_sources: bool = True):
    answer = rag_chain.invoke(question)
    print("❓", question)
    print("\n💬", answer)
    if show_sources:
        sources = retriever.invoke(question)
        seen = set()
        print("\n📄 Sources:")
        for d in sources:
            src = d.metadata.get("source", "unknown")
            if src not in seen:
                print("  -", src)
                seen.add(src)
    return answer

_ = ask("What is the company's refund policy?")

# %% [markdown]
# ## Step 10 — A simple interactive chat loop (optional)
#
# Run this cell to chat with your documents in a loop. Type `quit` (or `exit`) to stop.
#
# > Note: each question is answered independently — this bot has no conversational memory yet.
# > Adding memory (so it understands follow-ups like "what about for members?") is a great next step,
# > listed below.

# %%
print("Ask questions about your documents. Type 'quit' to stop.\n")
while True:
    try:
        q = input("You: ").strip()
    except (EOFError, KeyboardInterrupt):
        break
    if q.lower() in {"quit", "exit", ""}:
        print("Goodbye!")
        break
    print("Bot:", rag_chain.invoke(q), "\n")

# %% [markdown]
# ## 🎉 You built a local RAG Q&A bot!
#
# Recap of what each piece did:
# 1–3. **Loaded** your mixed-format documents.
# 4. **Split** them into overlapping chunks.
# 5. **Embedded** the chunks and stored them in a local **Chroma** database.
# 6. **Retrieved** the most relevant chunks per question.
# 7. **Prompt template** kept the bot grounded and honest.
# 8. **LCEL chain** tied retrieval → prompt → LLM together.
# 9–10. **Asked questions** and got answers cited from your own documents.
#
# ### Ideas to extend it (in rough order of difficulty)
# - **Conversational memory** — let it handle follow-up questions.
# - **Better citations** — show the exact snippet and page number used.
# - **A UI** — wrap it in [Streamlit](https://streamlit.io/) for a proper chat window.
# - **Tune retrieval** — experiment with `N_RESULTS`, `CHUNK_SIZE`, or try `MultiQueryRetriever`.
# - **Evaluate quality** — measure answer accuracy with a tool like Ragas.
# - **Package with Docker** — for reproducible deployment once you're happy with it.
